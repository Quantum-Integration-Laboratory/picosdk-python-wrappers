# %%
from qil_Pico import scope as pico
import matplotlib.pyplot as plt

# %%
scope=pico.scope()
A=scope.channel('A','2V')
t,y=A.getData(10,50000)

plt.plot(t,y)
plt.show()
plt.close()

scope.close()
